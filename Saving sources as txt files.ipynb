# %% [markdown]
# # Saving sources as txt files
#
# Script Purpose: Batch processes CSV files containing OCR-corrected text and converts them to individual TXT files.
#
# Key Operations:
#
# - Reads all CSV files from literature csv_clean folder
#
# - Extracts the ocr_corrected_text column from each CSV
#
# - Combines all text rows into a single string per file
#
# - Cleans the text by removing 'nan' values and extra whitespace
#
# - Saves each processed text as a separate TXT file in literature txt folder
#
# - Filters out non-CSV files and hidden directories to avoid permission errors
#
# - Provides progress feedback during processing

# %%
# Data manipulation and file operations
import pandas as pd  # For creating and managing DataFrames
import os  # For file and directory operations

# Progress tracking
from tqdm.notebook import tqdm  # Display progress bars in Jupyter notebooks
tqdm.pandas()

# %%
# ===================================================================
# BATCH PROCESSING: Process all csv files and store text as txt files
# ===================================================================

# Define input and output directories
departure_folder = r'.\literature csv_clean'     # Source folder containing clean CSV files
arrival_folder = r'.\literature txt'    # Destination folder for txt output

# Create the output directory if it doesn't exist
# exist_ok=True prevents errors if the directory already exists
os.makedirs(arrival_folder, exist_ok=True)

# Get a list of all files in the CSV folder
files_in_folder = os.listdir(departure_folder)

# Filter to only process CSV files and skip hidden files/folders
csv_files = [file for file in files_in_folder if file.endswith('.csv') and not file.startswith('.')]

print(f"Found {len(csv_files)} CSV files to process")

for file in csv_files:
    # Construct the full path to the CSV file
    file_path = os.path.join(departure_folder, file)
    df = pd.read_csv(file_path)
    _text = ' '.join(df['ocr_corrected_text'].astype(str).to_list())
    _text = _text.replace('nan', ' ').strip()
    
    # Create output filename by replacing .csv with .txt
    output_filename = file.replace('.csv', '.txt')
    output_path = os.path.join(arrival_folder, output_filename)
    
    # Save the text content to a txt file
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(_text)
    
    print(f"Processed: {file} -> {output_filename}")

print(f"\nBatch processing complete! All files saved to: {arrival_folder}")
# Out:
# Found 159 CSV files to process
# Processed: 1772 Travels through Holland Flanders Germany Denmark Sweden Lapland Russia the Ukraine and Poland in the years 1768 1769 and 1770 Vol 1.csv -> 1772 Travels through Holland Flanders Germany Denmark Sweden Lapland Russia the Ukraine and Poland in the years 1768 1769 and 1770 Vol 1.txt
# Processed: 1773 Travels through Holland Flanders Germany Denmark Sweden Lapland Russia the Ukraine and Poland in the years 1768 1769 and 1770 Vol 3.csv -> 1773 Travels through Holland Flanders Germany Denmark Sweden Lapland Russia the Ukraine and Poland in the years 1768 1769 and 1770 Vol 3.txt
# Processed: 1795 A tour through some of the northern parts of Europe.csv -> 1795 A tour through some of the northern parts of Europe.txt
# Processed: 1805 A northern summer.csv -> 1805 A northern summer.txt
# Processed: 1807 A Tour round the Baltic.csv -> 1807 A Tour round the Baltic.txt
# Processed: 1807 A tour through part of Germany Poland Russia Sweden Denmark.csv -> 1807 A tour through part of Germany Poland Russia Sweden Denmark.txt
# Processed: 1809 Travelling sketches in Russia and Sweden.csv -> 1809 Travelling sketches in Russia and Sweden.txt
# Processed: 1810 Travel through Denmark and part of Sweden during the winter and spring of the year 1809.csv -> 1810 Travel through Denmark and part of Sweden during the winter and spring of the year 1809.txt
# Processed: 1811 Journal of a Tour in Iceland in the Summer of 1809.csv -> 1811 Journal of a Tour in Iceland in the Summer of 1809.txt
# Processed: 1811 Travels in Iceland.csv -> 1811 Travels in Iceland.txt
# Processed: 1812 Travels in the island of Iceland during the summer of the year MDCCCX.csv -> 1812 Travels in the island of Iceland during the summer of the year MDCCCX.txt
# Processed: 1813 Travels in Sweden during the Autumn of 1812.csv -> 1813 Travels in Sweden during the Autumn of 1812.txt
# Processed: 1813 Travels through Norway and Lapland during the years 1806 1807 and 1808.csv -> 1813 Travels through Norway and Lapland during the years 1806 1807 and 1808.txt
# Processed: 1815 A Tour Through Sweden Swedish_Lapland Finland and Denmark.csv -> 1815 A Tour Through Sweden Swedish_Lapland Finland and Denmark.txt
# Processed: 1816 Journal of a Tour in Germany Sweden Russia Poland During the Years 1813 and 1814.csv -> 1816 Journal of a Tour in Germany Sweden Russia Poland During the Years 1813 and 1814.txt
# Processed: 1816 Sketches on a Tour to Copenhagen Through Norway and Sweden.csv -> 1816 Sketches on a Tour to Copenhagen Through Norway and Sweden.txt
# Processed: 1816 Travels Through Part of the Russian Empire and the Country of Poland Along the Southern Shores of the Baltic.csv -> 1816 Travels Through Part of the Russian Empire and the Country of Poland Along the Southern Shores of the Baltic.txt
# Processed: 1818 Iceland Or The Journal of a Residence in that Island During the Years 1814 and 1815 Vol 1.csv -> 1818 Iceland Or The Journal of a Residence in that Island During the Years 1814 and 1815 Vol 1.txt
# Processed: 1818 Iceland Or The Journal of a Residence in that Island During the Years 1814 and 1815 Vol 2.csv -> 1818 Iceland Or The Journal of a Residence in that Island During the Years 1814 and 1815 Vol 2.txt
# Processed: 1826 Travels in Norway Sweden Denmark Hanover Germany Netherlands.csv -> 1826 Travels in Norway Sweden Denmark Hanover Germany Netherlands.txt
# Processed: 1826 Travels in Sweden Denmark and Norway.csv -> 1826 Travels in Sweden Denmark and Norway.txt
# Processed: 1827 Travels in Norway Sweden Finland Russia and Turkey vol 1.csv -> 1827 Travels in Norway Sweden Finland Russia and Turkey vol 1.txt
# Processed: 1827 Travels in Norway Sweden Finland Russia and Turkey vol 2.csv -> 1827 Travels in Norway Sweden Finland Russia and Turkey vol 2.txt
# Processed: 1830 Field sports of the north of Europe vol 1.csv -> 1830 Field sports of the north of Europe vol 1.txt
# Processed: 1830 Field sports of the north of Europe vol 2.csv -> 1830 Field sports of the north of Europe vol 2.txt
# Processed: 1831 Iceland Or The Journal of a Residence in that Island.csv -> 1831 Iceland Or The Journal of a Residence in that Island.txt
# Processed: 1832 Letters from the north of Europe.csv -> 1832 Letters from the north of Europe.txt
# Processed: 1834 Excursions in the north of Europe through parts of Russia Finland Sweden Denmark and Norway.csv -> 1834 Excursions in the north of Europe through parts of Russia Finland Sweden Denmark and Norway.txt
# Processed: 1834 Norway Views of wild scenery and journal.csv -> 1834 Norway Views of wild scenery and journal.txt
# Processed: 1835 A Personal Narrative of a Journey Through Norway Part of Sweden and the Islands and States of Denmark.csv -> 1835 A Personal Narrative of a Journey Through Norway Part of Sweden and the Islands and States of Denmark.txt
# Processed: 1835 A Visit to Iceland.csv -> 1835 A Visit to Iceland.txt
# Processed: 1836 Journal of a Residence in Norway During the Years 1834 1835 and 1836.csv -> 1836 Journal of a Residence in Norway During the Years 1834 1835 and 1836.txt
# Processed: 1838 Recollections of a tour in the North of Europe in 1836-1837.csv -> 1838 Recollections of a tour in the North of Europe in 1836-1837.txt
# Processed: 1838 Travels in Various Countries of Scandinavia vol 1.csv -> 1838 Travels in Various Countries of Scandinavia vol 1.txt
# Processed: 1838 Travels in Various Countries of Scandinavia vol 2.csv -> 1838 Travels in Various Countries of Scandinavia vol 2.txt
# Processed: 1838 Travels in Various Countries of Scandinavia vol 3.csv -> 1838 Travels in Various Countries of Scandinavia vol 3.txt
# Processed: 1839 A Tour in Sweden in 1838.csv -> 1839 A Tour in Sweden in 1838.txt
# Processed: 1839 Handbook for travellers in Denmark Norway Sweden and Russia.csv -> 1839 Handbook for travellers in Denmark Norway Sweden and Russia.txt
# Processed: 1840 An Historical and Descriptive Account of Iceland, Greenland, and the Faroe Islands.csv -> 1840 An Historical and Descriptive Account of Iceland, Greenland, and the Faroe Islands.txt
# Processed: 1840 Excursions in Denmark Norway and Sweden vol 1.csv -> 1840 Excursions in Denmark Norway and Sweden vol 1.txt
# Processed: 1840 Norway and the Norwegians In Two Volumes vol 1.csv -> 1840 Norway and the Norwegians In Two Volumes vol 1.txt
# Processed: 1840 Norway and the Norwegians In Two Volumes vol 2.csv -> 1840 Norway and the Norwegians In Two Volumes vol 2.txt
# Processed: 1841 Visit to Northern Europe vol 1.csv -> 1841 Visit to Northern Europe vol 1.txt
# Processed: 1841 Visit to Northern Europe vol 2.csv -> 1841 Visit to Northern Europe vol 2.txt
# Processed: 1842 Letters from the Shores of the Baltic vol 1.csv -> 1842 Letters from the Shores of the Baltic vol 1.txt
# Processed: 1842 Letters from the Shores of the Baltic vol 2.csv -> 1842 Letters from the Shores of the Baltic vol 2.txt
# Processed: 1842 Travels in Iceland.csv -> 1842 Travels in Iceland.txt
# Processed: 1848 Handbook for Northern Europe Including Denmark Norway Sweden Finland and Russia.csv -> 1848 Handbook for Northern Europe Including Denmark Norway Sweden Finland and Russia.txt
# Processed: 1849 A Yacht Voyage to Norway Denmark and Sweden.csv -> 1849 A Yacht Voyage to Norway Denmark and Sweden.txt
# Processed: 1849 Handbook for Northern Europe Including Denmark Norway Sweden Finland and Russia vol 2.csv -> 1849 Handbook for Northern Europe Including Denmark Norway Sweden Finland and Russia vol 2.txt
# Processed: 1851 One year in Scandinavia.csv -> 1851 One year in Scandinavia.txt
# Processed: 1852 Observations on the Social and Political State of Denmark.csv -> 1852 Observations on the Social and Political State of Denmark.txt
# Processed: 1853 Life in Sweden vol 1.csv -> 1853 Life in Sweden vol 1.txt
# Processed: 1853 Life in Sweden vol 2.csv -> 1853 Life in Sweden vol 2.txt
# Processed: 1853 Norway and Its Glaciers.csv -> 1853 Norway and Its Glaciers.txt
# Processed: 1853 Norway and its scenery.csv -> 1853 Norway and its scenery.txt
# Processed: 1853 Visit to Iceland And the Scandinavian North.csv -> 1853 Visit to Iceland And the Scandinavian North.txt
# Processed: 1854 A Yacht Voyage to Iceland in 1853.csv -> 1854 A Yacht Voyage to Iceland in 1853.txt
# Processed: 1854 Norðurfari or Rambles in Iceland.csv -> 1854 Norðurfari or Rambles in Iceland.txt
# Processed: 1854 The Baltic Its Gates Shores and Cities.csv -> 1854 The Baltic Its Gates Shores and Cities.txt
# Processed: 1854 Travels and Adventures in Sweden and Norway.csv -> 1854 Travels and Adventures in Sweden and Norway.txt
# Processed: 1854 Travels on the Shores of the Baltic Extended to Moscow.csv -> 1854 Travels on the Shores of the Baltic Extended to Moscow.txt
# Processed: 1855 Forest Scenes in Norway and Sweden.csv -> 1855 Forest Scenes in Norway and Sweden.txt
# Processed: 1856 A Summer in Northern Europe.csv -> 1856 A Summer in Northern Europe.txt
# Processed: 1856 Europe vol 3 Residence in Norway Notes on France Russia etc.csv -> 1856 Europe vol 3 Residence in Norway Notes on France Russia etc.txt
# Processed: 1856 The Danes and the Swedes.csv -> 1856 The Danes and the Swedes.txt
# Processed: 1856 Tracings of Iceland and the Faroe Islands.csv -> 1856 Tracings of Iceland and the Faroe Islands.txt
# Processed: 1857 A long vacation ramble in Norway and Sweden.csv -> 1857 A long vacation ramble in Norway and Sweden.txt
# Processed: 1857 Letters from High Latitudes.csv -> 1857 Letters from High Latitudes.txt
# Processed: 1857 The book of the Baltic being the North of Europe Steam Companys route to Denmark Sweden and Russia Norway Prussia and the Hanseatic Ports.csv -> 1857 The book of the Baltic being the North of Europe Steam Companys route to Denmark Sweden and Russia Norway Prussia and the Hanseatic Ports.txt
# Processed: 1857 Unprotected Females in Norway.csv -> 1857 Unprotected Females in Norway.txt
# Processed: 1858 The Oxonian in Thelemarken vol 1.csv -> 1858 The Oxonian in Thelemarken vol 1.txt
# Processed: 1858 The Oxonian in Thelemarken vol 2.csv -> 1858 The Oxonian in Thelemarken vol 2.txt
# Processed: 1859 Northern Travel.csv -> 1859 Northern Travel.txt
# Processed: 1859 The Norse folk or A visit to the homes of Norway and Sweden.csv -> 1859 The Norse folk or A visit to the homes of Norway and Sweden.txt
# Processed: 1859 Through Norway with a knapsack.csv -> 1859 Through Norway with a knapsack.txt
# Processed: 1860 A Residence in Jutland the Danish Isles and Copenhagen vol I.csv -> 1860 A Residence in Jutland the Danish Isles and Copenhagen vol I.txt
# Processed: 1860 A Residence in Jutland the Danish Isles and Copenhagen vol II.csv -> 1860 A Residence in Jutland the Danish Isles and Copenhagen vol II.txt
# Processed: 1861 Seasons with the sea horses.csv -> 1861 Seasons with the sea horses.txt
# Processed: 1861 The Oxonian in Iceland.csv -> 1861 The Oxonian in Iceland.txt
# Processed: 1862 A tour in Northern Europe.csv -> 1862 A tour in Northern Europe.txt
# Processed: 1862 One year in Sweden including a visit to the isle of Gotland vol 1.csv -> 1862 One year in Sweden including a visit to the isle of Gotland vol 1.txt
# Processed: 1862 Pen and Pencil Sketches of Faroe and Iceland.csv -> 1862 Pen and Pencil Sketches of Faroe and Iceland.txt
# Processed: 1863 A Yachting Cruise in the Baltic.csv -> 1863 A Yachting Cruise in the Baltic.txt
# Processed: 1863 Iceland Its Scenes and Its Sagas.csv -> 1863 Iceland Its Scenes and Its Sagas.txt
# Processed: 1864 Chasing the Sun.csv -> 1864 Chasing the Sun.txt
# Processed: 1867 Sweden and Norway.csv -> 1867 Sweden and Norway.txt
# Processed: 1867 The Land of Thor.csv -> 1867 The Land of Thor.txt
# Processed: 1870 The Knapsack guide to Norway.csv -> 1870 The Knapsack guide to Norway.txt
# Processed: 1871 A Handbook for Travellers in Denmark Norway and Sweden third edition.csv -> 1871 A Handbook for Travellers in Denmark Norway and Sweden third edition.txt
# Processed: 1871 A handbook for travellers in Denmark Norway and Sweden.csv -> 1871 A handbook for travellers in Denmark Norway and Sweden.txt
# Processed: 1871 Canoe Travelling Log of a Cruise on the Baltic.csv -> 1871 Canoe Travelling Log of a Cruise on the Baltic.txt
# Processed: 1871 How to See Norway.csv -> 1871 How to See Norway.txt
# Processed: 1871 Up the Baltic Or Young America in Norway Sweden and Denmark.csv -> 1871 Up the Baltic Or Young America in Norway Sweden and Denmark.txt
# Processed: 1872 The Rob Roy on the Baltic.csv -> 1872 The Rob Roy on the Baltic.txt
# Processed: 1873 Tent Life with English Gipsies in Norway.csv -> 1873 Tent Life with English Gipsies in Norway.txt
# Processed: 1873 To Iceland in a Yacht.csv -> 1873 To Iceland in a Yacht.txt
# Processed: 1874 Wayside notes in Scandinavia.csv -> 1874 Wayside notes in Scandinavia.txt
# Processed: 1875 An American in Iceland.csv -> 1875 An American in Iceland.txt
# Processed: 1875 The Pilgrim of Scandinavia.csv -> 1875 The Pilgrim of Scandinavia.txt
# Processed: 1875 Ultima Thule or A Summer in Iceland vol 1.csv -> 1875 Ultima Thule or A Summer in Iceland vol 1.txt
# Processed: 1875 Ultima Thule or A Summer in Iceland vol 2.csv -> 1875 Ultima Thule or A Summer in Iceland vol 2.txt
# Processed: 1875 Up The Baltic  Or Young America in Norway Sweden and Denmark.csv -> 1875 Up The Baltic  Or Young America in Norway Sweden and Denmark.txt
# Processed: 1877 A summer holiday in Scandinavia.csv -> 1877 A summer holiday in Scandinavia.txt
# Processed: 1877 Scenes of travel in Norway.csv -> 1877 Scenes of travel in Norway.txt
# Processed: 1877 Six weeks in Norway.csv -> 1877 Six weeks in Norway.txt
# Processed: 1878 To the Arctic Regions and Back in Six Weeks.csv -> 1878 To the Arctic Regions and Back in Six Weeks.txt
# Processed: 1879 A holiday in Iceland.csv -> 1879 A holiday in Iceland.txt
# Processed: 1879 Diary of a tour in Sweden Norway and Russia in 1827 with letters.csv -> 1879 Diary of a tour in Sweden Norway and Russia in 1827 with letters.txt
# Processed: 1879 Gamle Norge Rambles and Scrambles in Norway.csv -> 1879 Gamle Norge Rambles and Scrambles in Norway.txt
# Processed: 1880 Five weeks in Iceland.csv -> 1880 Five weeks in Iceland.txt
# Processed: 1881 Denmark and Iceland.csv -> 1881 Denmark and Iceland.txt
# Processed: 1881 The story of a scandinavian summer.csv -> 1881 The story of a scandinavian summer.txt
# Processed: 1882 By Fell and Fjord.csv -> 1882 By Fell and Fjord.txt
# Processed: 1882 Summer travelling in Iceland.csv -> 1882 Summer travelling in Iceland.txt
# Processed: 1882 Sweden and Norway.csv -> 1882 Sweden and Norway.txt
# Processed: 1882 The Land of the Midnight Sun vol 1.csv -> 1882 The Land of the Midnight Sun vol 1.txt
# Processed: 1882 The Land of the Midnight Sun vol 2.csv -> 1882 The Land of the Midnight Sun vol 2.txt
# Processed: 1882 Three in Norway by Two of Them.csv -> 1882 Three in Norway by Two of Them.txt
# Processed: 1884 Driftwood from Scandinavia.csv -> 1884 Driftwood from Scandinavia.txt
# Processed: 1884 Zigzag Journeys in Northern Land.csv -> 1884 Zigzag Journeys in Northern Land.txt
# Processed: 1885 In the Northmans land.csv -> 1885 In the Northmans land.txt
# Processed: 1885 One and a Half in Norway.csv -> 1885 One and a Half in Norway.txt
# Processed: 1885 Sketches in Holland and Scandinavia.csv -> 1885 Sketches in Holland and Scandinavia.txt
# Processed: 1885 The viking Bodleys.csv -> 1885 The viking Bodleys.txt
# Processed: 1886 The midnight sun the tsar and the nihilist.csv -> 1886 The midnight sun the tsar and the nihilist.txt
# Processed: 1887 Due North.csv -> 1887 Due North.txt
# Processed: 1887 Glimpses of Scandinavia and Russia.csv -> 1887 Glimpses of Scandinavia and Russia.txt
# Processed: 1887 Norway Nights and Russian Days.csv -> 1887 Norway Nights and Russian Days.txt
# Processed: 1889 Letters Written During a Short Residence in Sweden Norway and Denmark.csv -> 1889 Letters Written During a Short Residence in Sweden Norway and Denmark.txt
# Processed: 1890 Norwegian Pictures.csv -> 1890 Norwegian Pictures.txt
# Processed: 1892 A Ride Across Iceland in the Summer of 1891.csv -> 1892 A Ride Across Iceland in the Summer of 1891.txt
# Processed: 1892 Norway and the Norwegians.csv -> 1892 Norway and the Norwegians.txt
# Processed: 1892 The best tour in Norway.csv -> 1892 The best tour in Norway.txt
# Processed: 1893 Old Norway and Its Fjords.csv -> 1893 Old Norway and Its Fjords.txt
# Processed: 1893 Sweden and the Swedes.csv -> 1893 Sweden and the Swedes.txt
# Processed: 1894 A Girls Ride in Iceland.csv -> 1894 A Girls Ride in Iceland.txt
# Processed: 1894 A Winter Jaunt to Norway.csv -> 1894 A Winter Jaunt to Norway.txt
# Processed: 1895 Angling travels in Norway.csv -> 1895 Angling travels in Norway.txt
# Processed: 1895 Notes of Travel in Sweden.csv -> 1895 Notes of Travel in Sweden.txt
# Processed: 1895 Vignette from Finland.csv -> 1895 Vignette from Finland.txt
# Processed: 1896 New ground in Norway.csv -> 1896 New ground in Norway.txt
# Processed: 1897 Norway.csv -> 1897 Norway.txt
# Processed: 1897 Wild Norway.csv -> 1897 Wild Norway.txt
# Processed: 1898 Again in Sweden.csv -> 1898 Again in Sweden.txt
# Processed: 1898 New Climbs in Norway.csv -> 1898 New Climbs in Norway.txt
# Processed: 1898 Through Finland in Carts.csv -> 1898 Through Finland in Carts.txt
# Processed: 1899 Ruins of the Saga Time.csv -> 1899 Ruins of the Saga Time.txt
# Processed: 1902 Across Iceland.csv -> 1902 Across Iceland.txt
# Processed: 1903 Thirty seasons in Scandinavia.csv -> 1903 Thirty seasons in Scandinavia.txt
# Processed: 1906 Through Scandinavia to Moscow.csv -> 1906 Through Scandinavia to Moscow.txt
# Processed: 1907 The Norwegian Fjords.csv -> 1907 The Norwegian Fjords.txt
# Processed: 1909 Peeps at many Lands Finland.csv -> 1909 Peeps at many Lands Finland.txt
# Processed: 1911 Peeps at Many Lands Norway.csv -> 1911 Peeps at Many Lands Norway.txt
# Processed: 1911 Two visits to Denmark 1872 1874.csv -> 1911 Two visits to Denmark 1872 1874.txt
# Processed: 1914 Capitals of the Northlands Tales of Ten Cities.csv -> 1914 Capitals of the Northlands Tales of Ten Cities.txt
# Processed: 1914 Iceland Horseback tours in saga land.csv -> 1914 Iceland Horseback tours in saga land.txt
# Processed: 1918 The Charm of Scandinavia.csv -> 1918 The Charm of Scandinavia.txt
# Processed: 1921 Denmark.csv -> 1921 Denmark.txt
#
# Batch processing complete! All files saved to: .\literature txt
